# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

start_year = 2013
end_year = 2023

movies_data_by_year = {}

for year in range(start_year, end_year+1):
    file_path = f'raw_data/tmdb_dump-{year}.csv'
    df = pd.read_csv(file_path, encoding='utf-8', lineterminator='\n')
    movies_data_by_year[year] = df
    print(year, len(df))
# Out:
# 2013 2690
# 2014 2794
# 2015 2961
# 2016 3060
# 2017 3331
# 2018 3287
# 2019 3223
# 2020 2466
# 2021 2456
# 2022 2435
# 2023 1912

# %%
for year in range(start_year, end_year+1):
    df = movies_data_by_year[year]
    print(year)
    print(df.isnull().sum())
    print("\n")
# Out:
# 2013
# adult                       0
# backdrop_path             375
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   29
# popularity                  0
# poster_path                18
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2375
# budget                      1
# genres                      1
# homepage                 1894
# imdb_id                    13
# production_companies        1
# production_countries        1
# revenue                     1
# runtime                     1
# spoken_languages            1
# status                      1
# tagline                  1494
# cast                        0
# crew                        0
# keywords                    3
# dtype: int64
#
#
# 2014
# adult                       0
# backdrop_path             358
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   43
# popularity                  0
# poster_path                18
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2458
# budget                      2
# genres                      2
# homepage                 2002
# imdb_id                    22
# production_companies        2
# production_countries        2
# revenue                     2
# runtime                     2
# spoken_languages            2
# status                      2
# tagline                  1573
# cast                        0
# crew                        0
# keywords                    1
# dtype: int64
#
#
# 2015
# adult                       0
# backdrop_path             299
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   39
# popularity                  0
# poster_path                 7
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2612
# budget                      3
# genres                      3
# homepage                 2017
# imdb_id                    13
# production_companies        3
# production_countries        3
# revenue                     3
# runtime                     3
# spoken_languages            3
# status                      3
# tagline                  1730
# cast                        3
# crew                        3
# keywords                    3
# dtype: int64
#
#
# 2016
# adult                       0
# backdrop_path             232
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   50
# popularity                  0
# poster_path                10
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2691
# budget                      3
# genres                      3
# homepage                 1985
# imdb_id                    17
# production_companies        3
# production_countries        3
# revenue                     3
# runtime                     4
# spoken_languages            3
# status                      3
# tagline                  1804
# cast                        4
# crew                        4
# keywords                    1
# dtype: int64
#
#
# 2017
# adult                       0
# backdrop_path             124
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   55
# popularity                  0
# poster_path                 6
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2971
# budget                      4
# genres                      4
# homepage                 2161
# imdb_id                    41
# production_companies        4
# production_countries        4
# revenue                     4
# runtime                     4
# spoken_languages            4
# status                      4
# tagline                  2096
# cast                        3
# crew                        3
# keywords                    2
# dtype: int64
#
#
# 2018
# adult                       0
# backdrop_path              79
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   55
# popularity                  0
# poster_path                 2
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2941
# budget                      2
# genres                      2
# homepage                 2049
# imdb_id                    20
# production_companies        2
# production_countries        2
# revenue                     2
# runtime                     2
# spoken_languages            2
# status                      2
# tagline                  1978
# cast                        0
# crew                        0
# keywords                    1
# dtype: int64
#
#
# 2019
# adult                       0
# backdrop_path              62
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   55
# popularity                  0
# poster_path                 2
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2853
# budget                      1
# genres                      1
# homepage                 1991
# imdb_id                    38
# production_companies        1
# production_countries        1
# revenue                     1
# runtime                     1
# spoken_languages            1
# status                      1
# tagline                  2013
# cast                        1
# crew                        1
# keywords                    5
# dtype: int64
#
#
# 2020
# adult                       0
# backdrop_path              73
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   42
# popularity                  0
# poster_path                 6
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2230
# budget                      1
# genres                      1
# homepage                 1480
# imdb_id                    40
# production_companies        1
# production_countries        1
# revenue                     1
# runtime                     1
# spoken_languages            1
# status                      1
# tagline                  1523
# cast                        1
# crew                        1
# keywords                    2
# dtype: int64
#
#
# 2021
# adult                       0
# backdrop_path              41
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   36
# popularity                  0
# poster_path                 1
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2181
# budget                      1
# genres                      1
# homepage                 1374
# imdb_id                    30
# production_companies        1
# production_countries        1
# revenue                     1
# runtime                     1
# spoken_languages            1
# status                      1
# tagline                  1423
# cast                        1
# crew                        1
# keywords                    1
# dtype: int64
#
#
# 2022
# adult                       0
# backdrop_path              25
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   41
# popularity                  0
# poster_path                 3
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    2178
# budget                      2
# genres                      2
# homepage                 1350
# imdb_id                    23
# production_companies        2
# production_countries        2
# revenue                     2
# runtime                     2
# spoken_languages            2
# status                      2
# tagline                  1406
# cast                        2
# crew                        2
# keywords                    0
# dtype: int64
#
#
# 2023
# adult                       0
# backdrop_path               9
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                   34
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# belongs_to_collection    1700
# budget                      1
# genres                      1
# homepage                 1071
# imdb_id                    23
# production_companies        1
# production_countries        1
# revenue                     1
# runtime                     1
# spoken_languages            1
# status                      1
# tagline                  1102
# cast                        4
# crew                        4
# keywords                    1
# dtype: int64

# %%
for year in range(start_year, end_year+1):
    df = movies_data_by_year[year]
    print(year)
    print(df[df == 0].count())
    print("\n")
# Out:
# 2013
# adult                    2690
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    2690
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   2079
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2174
# runtime                    42
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2014
# adult                    2794
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    2794
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   2219
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2271
# runtime                    53
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2015
# adult                    2961
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    2961
# vote_average                1
# vote_count                  0
# belongs_to_collection       0
# budget                   2413
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2471
# runtime                    53
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2016
# adult                    3060
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    3060
# vote_average                1
# vote_count                  1
# belongs_to_collection       0
# budget                   2509
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2518
# runtime                    61
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2017
# adult                    3331
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    3331
# vote_average                1
# vote_count                  1
# belongs_to_collection       0
# budget                   2807
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2765
# runtime                    76
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2018
# adult                    3287
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    3287
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   2800
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2797
# runtime                    72
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2019
# adult                    3223
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    3223
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   2789
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2728
# runtime                    57
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2020
# adult                    2466
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    2466
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   2204
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2135
# runtime                    45
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2021
# adult                    2456
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    2456
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   2173
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2104
# runtime                    43
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2022
# adult                    2435
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    2435
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   2111
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  2023
# runtime                    51
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64
#
#
# 2023
# adult                    1912
# backdrop_path               0
# genre_ids                   0
# id                          0
# original_language           0
# original_title              0
# overview                    0
# popularity                  0
# poster_path                 0
# release_date                0
# title                       0
# video                    1912
# vote_average                0
# vote_count                  0
# belongs_to_collection       0
# budget                   1578
# genres                      0
# homepage                    0
# imdb_id                     0
# production_companies        0
# production_countries        0
# revenue                  1532
# runtime                    67
# spoken_languages            0
# status                      0
# tagline                     0
# cast                        0
# crew                        0
# keywords                    0
# dtype: int64

# %%
for year in range(start_year, end_year+1):
    df = movies_data_by_year[year]
    print(year)
    print(df[df == ""].value_counts())
    print("\n")
# Out:
# 2013
# Series([], Name: count, dtype: int64)
#
#
# 2014
# Series([], Name: count, dtype: int64)
#
#
# 2015
# Series([], Name: count, dtype: int64)
#
#
# 2016
# Series([], Name: count, dtype: int64)
#
#
# 2017
# Series([], Name: count, dtype: int64)
#
#
# 2018
# Series([], Name: count, dtype: int64)
#
#
# 2019
# Series([], Name: count, dtype: int64)
#
#
# 2020
# Series([], Name: count, dtype: int64)
#
#
# 2021
# Series([], Name: count, dtype: int64)
#
#
# 2022
# Series([], Name: count, dtype: int64)
#
#
# 2023
# Series([], Name: count, dtype: int64)

# %%
for year in range(start_year, end_year+1):
    df = movies_data_by_year[year]
    print(year, df["budget"].value_counts(), df["revenue"].value_counts())
    print("\n")
# Out:
# 2013 budget
# 0.0           2079
# 5000000.0       24
# 1000000.0       24
# 2000000.0       24
# 4000000.0       15
#               ...
# 21000000.0       1
# 4800000.0        1
# 1900000.0        1
# 2900000.0        1
# 58000000.0       1
# Name: count, Length: 249, dtype: int64 revenue
# 0.0            2174
# 3900000.0         3
# 1600000.0         3
# 5200000.0         2
# 4463059.0         2
#                ...
# 12247.0           1
# 32935319.0        1
# 371900000.0       1
# 10900434.0        1
# 44000000.0        1
# Name: count, Length: 499, dtype: int64
#
#
# 2014 budget
# 0.0            2219
# 5000000.0        24
# 2000000.0        22
# 1000000.0        21
# 3000000.0        20
#                ...
# 12250000.0        1
# 120000000.0       1
# 7.0               1
# 2121476.0         1
# 41000000.0        1
# Name: count, Length: 246, dtype: int64 revenue
# 0.0            2271
# 3200000.0         3
# 100.0             3
# 2800000.0         2
# 4404.0            2
#                ...
# 83700000.0        1
# 529100000.0       1
# 369300000.0       1
# 542300000.0       1
# 120000.0          1
# Name: count, Length: 507, dtype: int64
#
#
# 2015 budget
# 0.0            2413
# 10000000.0       22
# 2000000.0        18
# 5000000.0        18
# 3000000.0        18
#                ...
# 176000000.0       1
# 64000000.0        1
# 34000000.0        1
# 25130430.0        1
# 7900000.0         1
# Name: count, Length: 251, dtype: int64 revenue
# 0.0            2471
# 8200000.0         3
# 5000000.0         3
# 1400000.0         2
# 150000000.0       2
#                ...
# 64800000.0        1
# 8000.0            1
# 4842699.0         1
# 41527.0           1
# 1034905.0         1
# Name: count, Length: 473, dtype: int64
#
#
# 2016 budget
# 0.0            2509
# 10000000.0       30
# 20000000.0       18
# 2000000.0        17
# 5000000.0        17
#                ...
# 313465.0          1
# 160000000.0       1
# 4480393.0         1
# 145000000.0       1
# 161690.0          1
# Name: count, Length: 248, dtype: int64 revenue
# 0.0            2518
# 1600000.0         3
# 1500000.0         3
# 10000000.0        3
# 2500000.0         2
#                ...
# 349779543.0       1
# 195243411.0       1
# 164989338.0       1
# 3924527.0         1
# 141067.0          1
# Name: count, Length: 520, dtype: int64
#
#
# 2017 budget
# 0.0           2807
# 10000000.0      26
# 1000000.0       21
# 3000000.0       14
# 30000000.0      13
#               ...
# 250.0            1
# 63900000.0       1
# 10778400.0       1
# 2331302.0        1
# 8616.0           1
# Name: count, Length: 270, dtype: int64 revenue
# 0.0           2765
# 6000000.0        3
# 2200000.0        3
# 165548.0         2
# 3600000.0        2
#               ...
# 9968972.0        1
# 26700000.0       1
# 53900000.0       1
# 5226331.0        1
# 14072400.0       1
# Name: count, Length: 540, dtype: int64
#
#
# 2018 budget
# 0.0            2800
# 10000000.0       20
# 2000000.0        19
# 1000000.0        17
# 20000000.0       15
#                ...
# 1050000.0         1
# 13749400.0        1
# 116000000.0       1
# 7280000.0         1
# 2.0               1
# Name: count, Length: 249, dtype: int64 revenue
# 0.0            2797
# 10000.0           3
# 3062477.0         2
# 1.0               2
# 4900000.0         2
#                ...
# 9300000.0         1
# 40500000.0        1
# 112790210.0       1
# 41657844.0        1
# 1544333.0         1
# Name: count, Length: 475, dtype: int64
#
#
# 2019 budget
# 0.0            2789
# 20000000.0       13
# 5000000.0        12
# 6000000.0        11
# 1000000.0        10
#                ...
# 17000000.0        1
# 4360174.0         1
# 5256817.0         1
# 152000000.0       1
# 1780456.0         1
# Name: count, Length: 225, dtype: int64 revenue
# 0.0            2728
# 577641.0          2
# 1401422.0         2
# 29.0              2
# 12000000.0        2
#                ...
# 120600000.0       1
# 77275.0           1
# 33856058.0        1
# 4700862.0         1
# 140195.0          1
# Name: count, Length: 480, dtype: int64
#
#
# 2020 budget
# 0.0            2204
# 5000000.0        10
# 2000000.0         7
# 1000000.0         6
# 18000000.0        5
#                ...
# 175000000.0       1
# 67000000.0        1
# 1400000.0         1
# 6900000.0         1
# 6.0               1
# Name: count, Length: 162, dtype: int64 revenue
# 0.0            2135
# 3700000.0         2
# 9500000.0         2
# 680418.0          2
# 11208529.0        2
#                ...
# 8921.0            1
# 111200000.0       1
# 11131254.0        1
# 28037.0           1
# 307143.0          1
# Name: count, Length: 327, dtype: int64
#
#
# 2021 budget
# 0.0            2173
# 20000000.0       19
# 10000000.0       11
# 5000000.0        11
# 200000000.0      10
#                ...
# 4900000.0         1
# 750000.0          1
# 13000000.0        1
# 20800000.0        1
# 1065465.0         1
# Name: count, Length: 150, dtype: int64 revenue
# 0.0           2104
# 5218666.0        2
# 13000000.0       2
# 2168905.0        2
# 847418.0         2
#               ...
# 68969.0          1
# 30500000.0       1
# 4500000.0        1
# 10237061.0       1
# 7100000.0        1
# Name: count, Length: 346, dtype: int64
#
#
# 2022 budget
# 0.0            2111
# 20000000.0       13
# 5000000.0         9
# 1000000.0         9
# 4000000.0         7
#                ...
# 460000000.0       1
# 165000000.0       1
# 1958878.0         1
# 2620000.0         1
# 36000000.0        1
# Name: count, Length: 178, dtype: int64 revenue
# 0.0            2023
# 13900000.0        3
# 289303.0          2
# 1300000.0         2
# 19200000.0        2
#                ...
# 940000000.0       1
# 405400000.0       1
# 859102154.0       1
# 15100000.0        1
# 1802922.0         1
# Name: count, Length: 401, dtype: int64
#
#
# 2023 budget
# 0.0            1578
# 20000000.0       11
# 10000000.0       10
# 15000000.0        9
# 2000000.0         8
#                ...
# 415000.0          1
# 19800000.0        1
# 250000000.0       1
# 65500000.0        1
# 13266839.0        1
# Name: count, Length: 198, dtype: int64 revenue
# 0.0            1532
# 20000000.0        2
# 3800000.0         2
# 18232.0           2
# 1100000.0         2
#                ...
# 476071180.0       1
# 83000000.0        1
# 146700000.0       1
# 76987621.0        1
# 79775114.0        1
# Name: count, Length: 362, dtype: int64

# %%
import ast

def remove_zero_entries(df):
    columns_to_check = [
        'id', 
        'original_language', 
        'original_title', 
        'overview',
        'release_date', 
        'title', 
        'vote_average', 
        'vote_count', 
        'genres', 
        'production_companies', 
        'production_countries', 
        'runtime', 
        'spoken_languages', 
        'cast', 
        'crew', 
        'keywords'
    ] 
    
    df_cleaned = df.dropna(subset=columns_to_check)
    
    zero_columns_condition = (df_cleaned[columns_to_check] == 0).any(axis=1)
    df_cleaned = df_cleaned[~zero_columns_condition]
    return df_cleaned

def map_production_countries(production_countries_col):
    return production_countries_col.map(lambda production_countries: [pd_dict['name'] for pd_dict in production_countries])

for year in range(start_year, end_year+1):
    df = movies_data_by_year[year]
    df = remove_zero_entries(df)
    df['production_countries'] = df['production_countries'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
    df['production_countries'] = map_production_countries(df['production_countries'])


    df_countries = df.explode('production_countries', ignore_index=True)
    country_counts = df_countries['production_countries'].value_counts().reset_index()
    country_counts.columns = ['production_country', 'count']
    
    # print(year, country_counts[country_counts["production_country"] == "Brazil"])
    total = df_countries[df_countries["production_countries"] == "Brazil"]["original_title"].count()
    without_budget = (df_countries[df_countries["production_countries"] == "Brazil"]["budget"] == 0).sum()
    
    print("Brasil:")
    print(year, total)
    # print(year, df_countries[df_countries["production_countries"] == "Brazil"]["original_title"].count(), "\n")
    # print(year, (df_countries[df_countries["production_countries"] == "Brazil"]["budget"] == 0).sum(), "\n")
    
    # print("EUA:")
    
    # total = df_countries[df_countries["production_countries"] == "United States of America"]["original_title"].count()
    # without_budget = (df_countries[df_countries["production_countries"] == "United States of America"]["budget"] == 0).sum()
    
    # print(year, total - without_budget)
    
    # print(len(df.index))
# Out:
# Brasil:
# 2013 41
# Brasil:
# 2014 55
# Brasil:
# 2015 45
# Brasil:
# 2016 56
# Brasil:
# 2017 90
# Brasil:
# 2018 69
# Brasil:
# 2019 70
# Brasil:
# 2020 42
# Brasil:
# 2021 44
# Brasil:
# 2022 32
# Brasil:
# 2023 34
